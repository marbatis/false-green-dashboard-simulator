# %% [markdown]
# # False Green Data Generation\nGenerate deterministic scenarios for analysis.

# %%
from app.simulation.scenario_factory import ScenarioFactory, ScenarioConfig\nfactory = ScenarioFactory()\ncfg = ScenarioConfig('retry_storm_masked_by_averages', 0.8, 24, 42)\nbundle = factory.generate(cfg)\nbundle.truth_metrics.keys()
